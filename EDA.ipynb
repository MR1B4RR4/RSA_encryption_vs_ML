# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', 10)

# %%
def aplicar_padding(lista, max_len, valor_padding=0):
    return lista + [valor_padding] * (max_len - len(lista))

# %%
df = pd.read_excel('DF_for_EDA.xlsx')
df.drop('Unnamed: 0', axis=1, inplace=True)
df.dropna(subset='token', inplace=True)
df.drop_duplicates(subset= 'word', inplace=True)
df = df.reset_index()
df.drop('index', axis=1, inplace=True)
df['encrypted_eval'] = df['encrypted'].apply(lambda x: eval(x))
df['token_cut_eval'] = df['token_cut'].apply(lambda x: eval(x))
median = np.median([len(i) for i in df['encrypted_eval']])
std = np.std([len(i) for i in df['encrypted_eval']])
df['encrypted_eval_len'] = df['encrypted_eval'].apply(lambda x: len(x))
df = df[df['encrypted_eval_len'] <= median + 2*std]
max_element = max([len(i) for i in df['encrypted_eval']])
df['encrypted_padded'] = df['encrypted_eval'].apply(lambda x: aplicar_padding(x, max_element))
df
# Out:
#               word                     token  \
# 0           love's              868996791793
# 1          majesty            87758479939499
# 2               To                      6289
# 3        frightful        809283818294809586
# 4     adversaries,  757896799293759283799322
# ...            ...                       ...
# 4340         fruit                8092958394
# 4341        table.              947576867924
# 4342       pasture            90759394959279
# 4343       viewing            96837997838881
# 4344      started.          9394759294797824
#
#                                  token_cut  \
# 0                       [8689, 9679, 1793]
# 1                 [8775, 8479, 9394, 9900]
# 2                                   [6289]
# 3           [8092, 8381, 8294, 8095, 8600]
# 4     [7578, 9679, 9293, 7592, 8379, 9322]
# ...                                    ...
# 4340                    [8092, 9583, 9400]
# 4341                    [9475, 7686, 7924]
# 4342              [9075, 9394, 9592, 7900]
# 4343              [9683, 7997, 8388, 8100]
# 4344              [9394, 7592, 9479, 7824]
#
#                                       encrypted  token_length  \
# 0                         [40023, 38259, 34971]            12
# 1                  [28831, 46223, 26544, 20148]            14
# 2                                        [7931]             4
# 3              [766, 13409, 33361, 48264, 1742]            18
# 4     [14513, 38259, 1184, 13627, 43874, 22621]            24
# ...                                         ...           ...
# 4340                         [766, 42936, 4519]            10
# 4341                      [12103, 46875, 43033]            12
# 4342                [1617, 26544, 24327, 14078]            14
# 4343                [14303, 36658, 35051, 5711]            14
# 4344               [26544, 13627, 24863, 15186]            16
#
#                                  encrypted_eval  \
# 0                         [40023, 38259, 34971]
# 1                  [28831, 46223, 26544, 20148]
# 2                                        [7931]
# 3              [766, 13409, 33361, 48264, 1742]
# 4     [14513, 38259, 1184, 13627, 43874, 22621]
# ...                                         ...
# 4340                         [766, 42936, 4519]
# 4341                      [12103, 46875, 43033]
# 4342                [1617, 26544, 24327, 14078]
# 4343                [14303, 36658, 35051, 5711]
# 4344               [26544, 13627, 24863, 15186]
#
#                             token_cut_eval  encrypted_eval_len  \
# 0                       [8689, 9679, 1793]                   3
# 1                 [8775, 8479, 9394, 9900]                   4
# 2                                   [6289]                   1
# 3           [8092, 8381, 8294, 8095, 8600]                   5
# 4     [7578, 9679, 9293, 7592, 8379, 9322]                   6
# ...                                    ...                 ...
# 4340                    [8092, 9583, 9400]                   3
# 4341                    [9475, 7686, 7924]                   3
# 4342              [9075, 9394, 9592, 7900]                   4
# 4343              [9683, 7997, 8388, 8100]                   4
# 4344              [9394, 7592, 9479, 7824]                   4
#
#                                encrypted_padded
# 0                [40023, 38259, 34971, 0, 0, 0]
# 1            [28831, 46223, 26544, 20148, 0, 0]
# 2                         [7931, 0, 0, 0, 0, 0]
# 3           [766, 13409, 33361, 48264, 1742, 0]
# 4     [14513, 38259, 1184, 13627, 43874, 22621]
# ...                                         ...
# 4340                [766, 42936, 4519, 0, 0, 0]
# 4341             [12103, 46875, 43033, 0, 0, 0]
# 4342          [1617, 26544, 24327, 14078, 0, 0]
# 4343          [14303, 36658, 35051, 5711, 0, 0]
# 4344         [26544, 13627, 24863, 15186, 0, 0]
#
# [4277 rows x 9 columns]

# %%
df = df[['token','encrypted_padded']]
df
# Out:
#                          token                           encrypted_padded
# 0                 868996791793             [40023, 38259, 34971, 0, 0, 0]
# 1               87758479939499         [28831, 46223, 26544, 20148, 0, 0]
# 2                         6289                      [7931, 0, 0, 0, 0, 0]
# 3           809283818294809586        [766, 13409, 33361, 48264, 1742, 0]
# 4     757896799293759283799322  [14513, 38259, 1184, 13627, 43874, 22621]
# ...                        ...                                        ...
# 4340                8092958394                [766, 42936, 4519, 0, 0, 0]
# 4341              947576867924             [12103, 46875, 43033, 0, 0, 0]
# 4342            90759394959279          [1617, 26544, 24327, 14078, 0, 0]
# 4343            96837997838881          [14303, 36658, 35051, 5711, 0, 0]
# 4344          9394759294797824         [26544, 13627, 24863, 15186, 0, 0]
#
# [4277 rows x 2 columns]

# %%
for i in range(max_element):
    # Asignar el valor correspondiente de la lista a cada nueva columna
    df[f'value_{i+1}'] = df['encrypted_padded'].apply(lambda x: x[i])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10264\3771069967.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'value_{i+1}'] = df['encrypted_padded'].apply(lambda x: x[i])
# C:\Users\USER\AppData\Local\Temp\ipykernel_10264\3771069967.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'value_{i+1}'] = df['encrypted_padded'].apply(lambda x: x[i])
# C:\Users\USER\AppData\Local\Temp\ipykernel_10264\3771069967.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'value_{i+1}'] = df['encrypted_padded'].apply(lambda x: x[i])
# C:\Users\USER\AppData\Local\Temp\ipykernel_10264\3771069967.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'value_{i+1}'] = df['encrypted_padded'].apply(lambda x: x[i])
# C:\Users\USER\AppData\Local\Temp\ipykernel_10264\3771069967.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'value_{i+1}'] = df['encrypted_padded'].apply(lambda x: x[i])
# C:\Users\USER\AppData\Local\Temp\ipykernel_10264\3771069967.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'value_{i+1}'] = df['encrypted_padded'].apply(lambda x: x[i])

# %%
df = df.drop('encrypted_padded', axis=1)

# %%
df.to_excel('DF_for_model_training.xlsx')

# %% [markdown]
# # New EDA for another model Training

# %%
df = pd.read_excel('DF_for_EDA.xlsx')
df.drop('Unnamed: 0', axis=1, inplace=True)
df.dropna(subset='token', inplace=True)
df.drop_duplicates(subset= 'word', inplace=True)
df = df.reset_index()
df.drop('index', axis=1, inplace=True)
df['encrypted_eval'] = df['encrypted'].apply(lambda x: eval(x))
df['token_cut_eval'] = df['token_cut'].apply(lambda x: eval(x))
median = np.median([len(i) for i in df['encrypted_eval']])
std = np.std([len(i) for i in df['encrypted_eval']])
df['encrypted_eval_len'] = df['encrypted_eval'].apply(lambda x: len(x))
df = df[df['encrypted_eval_len'] <= median + 2*std]
max_element = max([len(i) for i in df['encrypted_eval']])
df['encrypted_padded'] = df['encrypted_eval'].apply(lambda x: aplicar_padding(x, max_element))

# %%
df = df[['token_cut_eval','encrypted_eval']]

# %%
# Inicializar listas para almacenar los datos del nuevo DataFrame
tokens = []
encrypteds = []

# Iterar sobre cada fila del DataFrame original
for index, row in df.iterrows():
    # Obtener las listas de tokens y encriptados
    token_list = row['token_cut_eval']
    encrypted_list = row['encrypted_eval']
    
    # Asegurar que las listas tengan el mismo tamaño
    assert len(token_list) == len(encrypted_list), "Las listas no tienen el mismo tamaño"
    
    # Iterar sobre los elementos de las listas y agregarlos a las listas correspondientes
    for token, encrypted in zip(token_list, encrypted_list):
        tokens.append(token)
        encrypteds.append(encrypted)

# Crear el nuevo DataFrame con los datos recopilados
df_resultado = pd.DataFrame({
    "token": tokens,
    "encrypted": encrypteds
})

# Mostrar el nuevo DataFrame para verificar su estructura
df_resultado
# Out:
#        token  encrypted
# 0       8689      40023
# 1       9679      38259
# 2       1793      34971
# 3       8775      28831
# 4       8479      46223
# ...      ...        ...
# 15209   8100       5711
# 15210   9394      26544
# 15211   7592      13627
# 15212   9479      24863
# 15213   7824      15186
#
# [15214 rows x 2 columns]

# %%
df_resultado.to_excel('DF_for_model_training_2.xlsx')
